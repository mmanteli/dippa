# %%
import spacy

# %%
lem = spacy.load("fi_core_news_lg")
words = ['potilaan', 'tiedot', '.', 'nimi', ':', 'ernesto', '.', 'sukunimi', ':', 'rivera', 'bueno', '.', 'nhc', ':', '368503.', 'nass', ':', '26', '63514095', '.', 'osoite', ':', 'calle', 'miguel', 'benitez', '90', '.', 'kaupunki', '/', 'maakunta', ':', 'madrid', '.', 'cp', ':', '28016', '.', 'aputiedot', '.', 'syntymäaika', ':', '03/03/1946', '.', 'maa', 'espanja', '.', 'ikä', ':', '70', 'vuotta', 'sukupuoli', ':', 'm', '.', 'ilmoittautumispäivä', ':', '12.12.2016', '.', 'lääkäri', ':', 'ignacio', 'navarro', 'cuéllar', 'ev', '.', ':', '28', '28', '70973', '.', 'potilaan', 'kliininen', 'selvitys', ':', '70-vuotias', 'potilas', ',', 'eläkkeellä', 'oleva', 'kaivostyöntekijä', ',', 'jolla', 'ei', 'ole', 'tiedossa', 'olevaa', 'lääkeaineallergiaa', ',', 'joka', 'esiintyy', 'henkilökohtaisena', 'historiana', ':', 'vanha', 'työtapaturma', 'nikama', '-', 'ja', 'kylkiluumurtumilla', ';', 'hänelle', 'leikattiin', 'dupuytrenin', 'tauti', 'oikeasta', 'kädestä', 'ja', 'vasemmasta', 'iliofemoraalinen', 'ohitusleikkaus', ';', 'diabetes', 'mellitus', 'tyyppi', 'ii', ',', 'hyperkolesterolemia', 'ja', 'hyperurikemia', ';', 'aktiivinen', 'alkoholismi', ',', 'polttaa', '20', 'savuketta', '/', 'päivä', '.', 'lähettäjä', ':', 'ignacio', 'navarro', 'cuéllar', 'c', '/', 'del', 'abedul', '5-7', ',', '2o', 'dcha', '28036', 'madrid', ',', 'espanja', 'sähköposti', ':', 'nnavcu', '@', 'hotmail', '.', 'com', '.', '</s>']
doc = lem(" ".join(words))
for token in doc:
    #print(token.text, token.pos_, token.dep_)
    print(token.lemma_)
# Out:
# potilas
# tieto
# .
# nimi
# :
# ernesto
# .
# sukunimi
# :
# rivera
# bueno
# .
# nhc
# :
# 368503
# .
# nass
# :
# 26
# 63514095
# .
# osoite
# :
# ca
# miguel
# benitez
# 90.
# .
# kaupunki
# /
# maakunta
# :
# madrid
# .
# cp
# :
# 28016
# .
# aputieto
# .
# syntymäaika
# :
# 03/03/1946.
# .
# maa
# Espanja
# .
# ikä
# :
# 70
# vuosi
# sukupuoli
# :
# m
# .
# ilmoittautumispäivä
# :
# 12.12.2016.
# .
# lääkäri
# :
# ignacio
# navarro
# cuéllar
# ev
# .
# :
# 28
# 28
# 70973
# .
# potilas
# kliininen
# selvitys
# :
# 70vuotias
# potilas
# ,
# eläkkee
# olla
# kaivostyöntekijä
# ,
# joka
# ei
# olla
# tieto
# olla
# lääkeaineallergia
# ,
# joka
# esiintyä
# henkilökohtainen
# historia
# :
# vanha
# työtapaturma
# nikama
# -
# ja
# kylkiluumurtumi
# ;
# hän
# leikattiin
# dupuytreti
# tauti
# oikea
# käsi
# ja
# vasemma
# iliofemoraalinen
# ohitusleikkaus
# ;
# diabetes
# mellitus
# tyyppi
# ii
# ,
# hyperkolesterolema
# ja
# hyperurikemia
# ;
# aktiivinen
# alkoholismi
# ,
# ...
